# %% [markdown]
# # Project-1, graphene nanoribbon with zigzag edges, 2014550025

# %%
import pybinding as pb
import numpy as np
import matplotlib.pyplot as plt

pb.pltutils.use_style()
# %matplotlib inline

# %%
from math import sqrt

def graphene_model():
    #a = 0.24595   # [nm] unit cell length
    #a_cc = 0.142  # [nm] carbon-carbon distance
    d = 0.142  # [nm] carbon-carbon distance
    t = -2.8      # [eV] nearest neighbour hopping

    lat = pb.Lattice(a1=[d*7*sqrt(3), 0],a2=[0,d*12])
    lat.add_sublattices(
                        ('0', [0, 0]),
                        ('1', [d*sqrt(3)/2, d/2]),
                        ('2', [d*sqrt(3)/2, d*3/2]),
                        ('3', [0, d*2]),
                        ('4', [0, d*3]),
                        ('5', [d*sqrt(3)/2,  d*7/2]),
                        ('6', [d*sqrt(3)/2,  d*9/2]),
                        ('7', [0, d*5]),
                        ('8', [0, d*6]),
                        ('9', [d*sqrt(3)/2,  d*13/2]),
                        ('10', [d*sqrt(3)/2, d*15/2]),
                        ('11', [0, d*8]),
                        ('12', [0, d*9]),
                        ('13', [d*sqrt(3)/2, d*19/2]),
                        ('14', [d*sqrt(3)/2, d*21/2]),
                        ('15', [0, d*11]),
                        
                        ('16', [1*d*sqrt(3), 0]),
                        ('17', [1*d*sqrt(3)+d*sqrt(3)/2, d/2]),
                        ('18', [1*d*sqrt(3)+d*sqrt(3)/2, d*3/2]),
                        ('19', [1*d*sqrt(3), d*2]),
                        ('20', [1*d*sqrt(3), d*3]),
                        ('21', [1*d*sqrt(3)+d*sqrt(3)/2,  d*7/2]),
                        ('22', [1*d*sqrt(3)+d*sqrt(3)/2,  d*9/2]),
                        ('23', [1*d*sqrt(3), d*5]),
                        ('24', [1*d*sqrt(3), d*6]),
                        ('25', [1*d*sqrt(3)+d*sqrt(3)/2,  d*13/2]),
                        ('26', [1*d*sqrt(3)+d*sqrt(3)/2, d*15/2]),
                        ('27', [1*d*sqrt(3), d*8]),
                        ('28', [1*d*sqrt(3), d*9]),
                        ('29', [1*d*sqrt(3)+d*sqrt(3)/2, d*19/2]),
                        ('30', [1*d*sqrt(3)+d*sqrt(3)/2, d*21/2]),
                        ('31', [1*d*sqrt(3), d*11]),
        
                        ('32', [2*d*sqrt(3), 0]),
                        ('33', [2*d*sqrt(3)+d*sqrt(3)/2, d/2]),
                        ('34', [2*d*sqrt(3)+d*sqrt(3)/2, d*3/2]),
                        ('35', [2*d*sqrt(3), d*2]),
                        ('36', [2*d*sqrt(3), d*3]),
                        ('37', [2*d*sqrt(3)+d*sqrt(3)/2,  d*7/2]),
                        ('38', [2*d*sqrt(3)+d*sqrt(3)/2,  d*9/2]),
                        ('39', [2*d*sqrt(3), d*5]),
                        ('40', [2*d*sqrt(3), d*6]),
                        ('41', [2*d*sqrt(3)+d*sqrt(3)/2,  d*13/2]),
                        ('42', [2*d*sqrt(3)+d*sqrt(3)/2, d*15/2]),
                        ('43', [2*d*sqrt(3), d*8]),
                        ('44', [2*d*sqrt(3), d*9]),
                        ('45', [2*d*sqrt(3)+d*sqrt(3)/2, d*19/2]),
                        ('46', [2*d*sqrt(3)+d*sqrt(3)/2, d*21/2]),
                        ('47', [2*d*sqrt(3), d*11]),

                        ('48', [3*d*sqrt(3), 0]),
                        ('49', [3*d*sqrt(3)+d*sqrt(3)/2, d/2]),
                        ('50', [3*d*sqrt(3)+d*sqrt(3)/2, d*3/2]),
                        ('51', [3*d*sqrt(3), d*2]),
                        ('52', [3*d*sqrt(3), d*3]),
                        ('53', [3*d*sqrt(3)+d*sqrt(3)/2,  d*7/2]),
                        ('54', [3*d*sqrt(3)+d*sqrt(3)/2,  d*9/2]),
                        ('55', [3*d*sqrt(3), d*5]),
                        ('56', [3*d*sqrt(3), d*6]),
                        ('57', [3*d*sqrt(3)+d*sqrt(3)/2,  d*13/2]),
                        ('58', [3*d*sqrt(3)+d*sqrt(3)/2, d*15/2]),
                        ('59', [3*d*sqrt(3), d*8]),
                        ('60', [3*d*sqrt(3), d*9]),
                        ('61', [3*d*sqrt(3)+d*sqrt(3)/2, d*19/2]),
                        ('62', [3*d*sqrt(3)+d*sqrt(3)/2, d*21/2]),
                        ('63', [3*d*sqrt(3), d*11]),

                        ('64', [4*d*sqrt(3), 0]),
                        ('65', [4*d*sqrt(3)+d*sqrt(3)/2, d/2]),
                        ('66', [4*d*sqrt(3)+d*sqrt(3)/2, d*3/2]),
                        ('67', [4*d*sqrt(3), d*2]),
                        ('68', [4*d*sqrt(3), d*3]),
                        ('69', [4*d*sqrt(3)+d*sqrt(3)/2,  d*7/2]),
                        ('70', [4*d*sqrt(3)+d*sqrt(3)/2,  d*9/2]),
                        ('71', [4*d*sqrt(3), d*5]),
                        ('72', [4*d*sqrt(3), d*6]),
                        ('73', [4*d*sqrt(3)+d*sqrt(3)/2,  d*13/2]),
                        ('74', [4*d*sqrt(3)+d*sqrt(3)/2, d*15/2]),
                        ('75', [4*d*sqrt(3), d*8]),
                        ('76', [4*d*sqrt(3), d*9]),
                        ('77', [4*d*sqrt(3)+d*sqrt(3)/2, d*19/2]),
                        ('78', [4*d*sqrt(3)+d*sqrt(3)/2, d*21/2]),
                        ('79', [4*d*sqrt(3), d*11]),

                        ('80', [5*d*sqrt(3), 0]),
                        ('81', [5*d*sqrt(3)+d*sqrt(3)/2, d/2]),
                        ('82', [5*d*sqrt(3)+d*sqrt(3)/2, d*3/2]),
                        ('83', [5*d*sqrt(3), d*2]),
                        ('84', [5*d*sqrt(3), d*3]),
                        ('85', [5*d*sqrt(3)+d*sqrt(3)/2,  d*7/2]),
                        ('86', [5*d*sqrt(3)+d*sqrt(3)/2,  d*9/2]),
                        ('87', [5*d*sqrt(3), d*5]),
                        ('88', [5*d*sqrt(3), d*6]),
                        ('89', [5*d*sqrt(3)+d*sqrt(3)/2,  d*13/2]),
                        ('90', [5*d*sqrt(3)+d*sqrt(3)/2, d*15/2]),
                        ('91', [5*d*sqrt(3), d*8]),
                        ('92', [5*d*sqrt(3), d*9]),
                        ('93', [5*d*sqrt(3)+d*sqrt(3)/2, d*19/2]),
                        ('94', [5*d*sqrt(3)+d*sqrt(3)/2, d*21/2]),
                        ('95', [5*d*sqrt(3), d*11]),
        
                        ('96', [6*d*sqrt(3), 0]),
                        ('97', [6*d*sqrt(3)+d*sqrt(3)/2, d/2]),
                        ('98', [6*d*sqrt(3)+d*sqrt(3)/2, d*3/2]),
                        ('99', [6*d*sqrt(3), d*2]),
                        ('100', [6*d*sqrt(3), d*3]),
                        ('101', [6*d*sqrt(3)+d*sqrt(3)/2,  d*7/2]),
                        ('102', [6*d*sqrt(3)+d*sqrt(3)/2,  d*9/2]),
                        ('103', [6*d*sqrt(3), d*5]),
                        ('104', [6*d*sqrt(3), d*6]),
                        ('105', [6*d*sqrt(3)+d*sqrt(3)/2,  d*13/2]),
                        ('106', [6*d*sqrt(3)+d*sqrt(3)/2, d*15/2]),
                        ('107', [6*d*sqrt(3), d*8]),
                        ('108', [6*d*sqrt(3), d*9]),
                        ('109', [6*d*sqrt(3)+d*sqrt(3)/2, d*19/2]),
                        ('110', [6*d*sqrt(3)+d*sqrt(3)/2, d*21/2]),
                        ('111', [6*d*sqrt(3), d*11])
                       )
    lat.add_hoppings(
        # inside the main cell, chain shape
        ([0,  0], '0', '1', t),
        ([0,  0], '1', '2', t),
        ([0,  0], '2', '3', t),
        ([0,  0], '3', '4', t),
        ([0,  0], '4', '5', t),
        ([0,  0], '5', '6', t),
        ([0,  0], '6', '7', t),
        ([0,  0], '7', '8', t),
        ([0,  0], '8', '9', t),
        ([0,  0], '9', '10', t),
        ([0,  0], '10', '11', t),
        ([0,  0], '11', '12', t),
        ([0,  0], '12', '13', t),
        ([0,  0], '13', '14', t),
        ([0,  0], '14', '15', t),
        
        ([0,  0], '16', '17', t),
        ([0,  0], '17', '18', t),
        ([0,  0], '18', '19', t),
        ([0,  0], '19', '20', t),
        ([0,  0], '20', '21', t),
        ([0,  0], '21', '22', t),
        ([0,  0], '22', '23', t),
        ([0,  0], '23', '24', t),
        ([0,  0], '24', '25', t),
        ([0,  0], '25', '26', t),
        ([0,  0], '26', '27', t),
        ([0,  0], '27', '28', t),
        ([0,  0], '28', '29', t),
        ([0,  0], '29', '30', t),
        ([0,  0], '30', '31', t),
        
        ([0,  0], '32', '33', t),
        ([0,  0], '33', '34', t),
        ([0,  0], '34', '35', t),
        ([0,  0], '35', '36', t),
        ([0,  0], '36', '37', t),
        ([0,  0], '37', '38', t),
        ([0,  0], '38', '39', t),
        ([0,  0], '39', '40', t),
        ([0,  0], '40', '41', t),
        ([0,  0], '41', '42', t),
        ([0,  0], '42', '43', t),
        ([0,  0], '43', '44', t),
        ([0,  0], '44', '45', t),
        ([0,  0], '45', '46', t),
        ([0,  0], '46', '47', t),
        
        ([0,  0], '48', '49', t),
        ([0,  0], '49', '50', t),
        ([0,  0], '50', '51', t),
        ([0,  0], '51', '52', t),
        ([0,  0], '52', '53', t),
        ([0,  0], '53', '54', t),
        ([0,  0], '54', '55', t),
        ([0,  0], '55', '56', t),
        ([0,  0], '56', '57', t),
        ([0,  0], '57', '58', t),
        ([0,  0], '58', '59', t),
        ([0,  0], '59', '60', t),
        ([0,  0], '60', '61', t),
        ([0,  0], '61', '62', t),
        ([0,  0], '62', '63', t),
        
        ([0,  0], '64', '65', t),
        ([0,  0], '65', '66', t),
        ([0,  0], '66', '67', t),
        ([0,  0], '67', '68', t),
        ([0,  0], '68', '69', t),
        ([0,  0], '69', '70', t),
        ([0,  0], '70', '71', t),
        ([0,  0], '71', '72', t),
        ([0,  0], '72', '73', t),
        ([0,  0], '73', '74', t),
        ([0,  0], '74', '75', t),
        ([0,  0], '75', '76', t),
        ([0,  0], '76', '77', t),
        ([0,  0], '77', '78', t),
        ([0,  0], '78', '79', t),
        
        ([0,  0], '80', '81', t),
        ([0,  0], '81', '82', t),
        ([0,  0], '82', '83', t),
        ([0,  0], '83', '84', t),
        ([0,  0], '84', '85', t),
        ([0,  0], '85', '86', t),
        ([0,  0], '86', '87', t),
        ([0,  0], '87', '88', t),
        ([0,  0], '88', '89', t),
        ([0,  0], '89', '90', t),
        ([0,  0], '90', '91', t),
        ([0,  0], '91', '92', t),
        ([0,  0], '92', '93', t),
        ([0,  0], '93', '94', t),
        ([0,  0], '94', '95', t),
        
        ([0,  0], '96', '97', t),
        ([0,  0], '97', '98', t),
        ([0,  0], '98', '99', t),
        ([0,  0], '99', '100', t),
        ([0,  0], '100', '101', t),
        ([0,  0], '101', '102', t),
        ([0,  0], '102', '103', t),
        ([0,  0], '103', '104', t),
        ([0,  0], '104', '105', t),
        ([0,  0], '105', '106', t),
        ([0,  0], '106', '107', t),
        ([0,  0], '107', '108', t),
        ([0,  0], '108', '109', t),
        ([0,  0], '109', '110', t),
        ([0,  0], '110', '111', t),        
        # inside the main cell, between chains
        ([0,  0], '1', '16', t),
        ([0,  0], '2', '19', t),
        ([0,  0], '5', '20', t),
        ([0,  0], '6', '23', t),
        ([0,  0], '9', '24', t),
        ([0,  0], '10', '27', t),
        ([0,  0], '13', '28', t),
        ([0,  0], '14', '31', t),
        
        ([0,  0], '17', '32', t),
        ([0,  0], '18', '35', t),
        ([0,  0], '21', '36', t),
        ([0,  0], '22', '39', t),
        ([0,  0], '25', '40', t),
        ([0,  0], '26', '43', t),
        ([0,  0], '29', '44', t),
        ([0,  0], '30', '47', t),
        
        ([0,  0], '33', '48', t),
        ([0,  0], '34', '51', t),
        ([0,  0], '37', '52', t),
        ([0,  0], '38', '55', t),
        ([0,  0], '41', '56', t),
        ([0,  0], '42', '59', t),
        ([0,  0], '45', '60', t),
        ([0,  0], '46', '63', t),
        
        ([0,  0], '49', '64', t),
        ([0,  0], '50', '67', t),
        ([0,  0], '53', '68', t),
        ([0,  0], '54', '71', t),
        ([0,  0], '57', '72', t),
        ([0,  0], '58', '75', t),
        ([0,  0], '61', '76', t),
        ([0,  0], '62', '79', t),
        
        ([0,  0], '65', '80', t),
        ([0,  0], '66', '83', t),
        ([0,  0], '69', '84', t),
        ([0,  0], '70', '87', t),
        ([0,  0], '73', '88', t),
        ([0,  0], '74', '91', t),
        ([0,  0], '77', '92', t),
        ([0,  0], '78', '95', t),
        
        ([0,  0], '81', '96', t),
        ([0,  0], '82', '99', t),
        ([0,  0], '85', '100', t),
        ([0,  0], '86', '103', t),
        ([0,  0], '89', '104', t),
        ([0,  0], '90', '107', t),
        ([0,  0], '93', '108', t),
        ([0,  0], '94', '111', t),
        
        # between neighboring cells, x directional
        ([-1, 0], '0', '97', t),
        ([-1, 0], '3', '98', t),
        ([-1, 0], '4', '101', t),
        ([-1, 0], '7', '102', t),
        ([-1, 0], '8', '105', t),
        ([-1, 0], '11', '106', t),
        ([-1, 0], '12', '109', t),
        ([-1, 0], '15', '110', t),
        # between neighboring cells, y directional
        ([0, -1], '0', '15', t),
        ([0, -1], '16', '31', t),
        ([0, -1], '32', '47', t),
        ([0, -1], '48', '63', t),
        ([0, -1], '64', '79', t),
        ([0, -1], '80', '95', t),
        ([0, -1], '96', '111', t)
    )
    return lat

lattice = graphene_model()
lattice.plot()
plt.show()

# %%
#from pybinding.repository import graphene
model = pb.Model(
    graphene_model(),
    pb.translational_symmetry(a1=False, a2= False)
)

model.plot()
#print(model.hamiltonian.todense())

# %%
from pybinding.repository import graphene
from math import sqrt, pi
plt.rcParams['figure.figsize']=(30,5)
model = pb.Model(
    graphene_model(),
    pb.translational_symmetry(a1=True, a2= True)
)
#print(model.hamiltonian.todense())

plt.subplot(141)
model.plot()
plt.title('Model system')
plt.show()

solver = pb.solver.lapack(model)
#print(solver.eigenvalues)

plt.subplot(142)
bands = solver.calc_bands(-pi/(7*graphene.a), pi/(7*graphene.a)) #in the first Brillouin zone, for kx
bands.plot(point_labels=[r"$-\pi / a$", r"$\pi / a$"])
plt.title('Band structure')
plt.show()

plt.subplot(143)
dos = solver.calc_dos(energies=np.linspace(-1, 1, 200), broadening=0.05)  # [eV]
dos.plot()
plt.title('Density of states')
plt.show()

plt.subplot(144)
reference_energy=0
ldos_map = solver.calc_spatial_ldos(energy=reference_energy, broadening=0.05)  # [eV]
ldos_map.plot()
pb.pltutils.colorbar(label='at energy %d'%reference_energy)
plt.title('Local density of states')
plt.show()

# %%
kpm = pb.kpm(model)

ldos = kpm.calc_ldos(energy=np.linspace(-8, 8, 500), broadening=0.5, position=[0, graphene.a])
ldos.plot()

# %%
from pybinding.repository import graphene

modelg = pb.Model(graphene.monolayer(), pb.rectangle(60, 60))
kpm = pb.kpm(modelg)

ldos = kpm.calc_ldos(energy=np.linspace(-8, 8, 200), broadening=0.05, position=[0, 0])
ldos.plot()

# %% [markdown]
# # Addtion atom on the specific site in unit cell

# %%
def addatom(delta_energy):
    @pb.onsite_energy_modifier
    def potential(energy, sub_id):
        energy[sub_id == '54'] += delta_energy
        energy[sub_id == '55'] += delta_energy
        energy[sub_id == '56'] += delta_energy
        energy[sub_id == '57'] += delta_energy
        energy[sub_id == '71'] += delta_energy
        energy[sub_id == '72'] += delta_energy
        return energy
    return potential

model = pb.Model(
    graphene_model(),
    pb.translational_symmetry(a1=True, a2= True),
    addatom(1)
)
#print(model3.hamiltonian.todense())

model.onsite_map.plot_contourf()
pb.pltutils.colorbar(label="U (eV)")
model.plot()
plt.title('Model system')
#model.lattice.plot_vectors(position=[0.6, -0.25])
# Out:
# Text(0.5, 1.0, 'Model system')

# %%
from pybinding.repository import graphene
from math import sqrt, pi

solver = pb.solver.lapack(model)
#print(solver.eigenvalues)

plt.subplot(142)
bands = solver.calc_bands(-pi/(7*graphene.a), pi/(7*graphene.a)) #in the first Brillouin zone, for kx
bands.plot(point_labels=[r"$-\pi / a$", r"$\pi / a$"])
plt.title('Band structure')
plt.show()

plt.subplot(143)
dos = solver.calc_dos(energies=np.linspace(-1, 1, 200), broadening=0.05)  # [eV]
dos.plot()
plt.title('Density of states')
plt.show()

plt.subplot(144)
reference_energy=0
ldos_map = solver.calc_spatial_ldos(energy=reference_energy, broadening=0.05)  # [eV]
ldos_map.plot()
pb.pltutils.colorbar(label='at energy %d'%reference_energy)
plt.title('Local density of states')
plt.show()

# %% [markdown]
# ## Make vacancies

# %%
def vacancy(atom):
    @pb.site_state_modifier
    def modifier(state, sub_id):
        state[sub_id==atom] = False
        return state
    return modifier
model = pb.Model(
    graphene_model(),
    pb.translational_symmetry(a1=True, a2= True),
    vacancy('2')
)
#print(model3_v.hamiltonian.todense())

model.plot()
plt.title('Model system')
# Out:
# Text(0.5, 1.0, 'Model system')

# %%
from pybinding.repository import graphene
from math import sqrt, pi

solver = pb.solver.lapack(model)
#print(solver.eigenvalues)

plt.subplot(142)
bands = solver.calc_bands(-pi/(7*graphene.a), pi/(7*graphene.a)) #in the first Brillouin zone, for kx
bands.plot(point_labels=[r"$-\pi / a$", r"$\pi / a$"])
plt.title('Band structure')
plt.show()

plt.subplot(143)
dos = solver.calc_dos(energies=np.linspace(-10, 10, 200), broadening=0.1)  # [eV]
dos.plot()
plt.title('Density of states')
plt.show()
print(dos.data[100])

plt.subplot(144)
reference_energy=0
ldos_map = solver.calc_spatial_ldos(energy=reference_energy, broadening=0.05)  # [eV]
ldos_map.plot()
pb.pltutils.colorbar(label='at energy %d'%reference_energy)
plt.title('Local density of states')
plt.show()
# Out:
# 3.540605266653058

# %%
for i in range(112):
    atom_id=str(i)
    def vacancy(atom):
        @pb.site_state_modifier
        def modifier(state, sub_id):
            state[sub_id==atom] = False
            return state
        return modifier
    model = pb.Model(
        graphene_model(),
        pb.translational_symmetry(a1=True, a2= True),
        vacancy(atom_id)
    )
    #print(model3_v.hamiltonian.todense())
    solver = pb.solver.lapack(model)
    
    #model.plot()
    #plt.title('Model system')
    dos = solver.calc_dos(energies=np.linspace(-10, 10, 200), broadening=0.05)  # [eV]
    #dos.plot()
    #plt.title('Density of states')
    print(dos.data[100])
# Out:
# 4.815188331229425
# 4.8153729356580826
# 4.815188331229425
# 4.815188331229425
# 4.815465237898619
# 4.815096029041437
# 4.815188331229425
# 4.815003726871098
# 4.815096029041437
# 4.8152806334349965
# 4.815003726871098
# 4.815188331229425
# 4.8152806334349965
# 4.815003726871098
# 4.815096029041437
# 4.815188331229425
# 4.815096029041437
# 4.815096029041437
# 4.814911424718477
# 4.815188331229425
# 4.815096029041437
# 4.815188331229425
# 4.814911424718477
# 4.815003726871098
# 4.815188331229425
# 4.8152806334349965
# 4.815003726871098
# 4.815003726871098
# 4.815096029041437
# 4.815003726871098
# 4.814911424718477
# 4.815188331229425
# 4.815096029041437
# 4.8153729356580826
# 4.815188331229425
# 4.815188331229425
# 4.815096029041437
# 4.815003726871098
# 4.815003726871098
# 4.815188331229425
# 4.8152806334349965
# 4.814911424718477
# 4.815003726871098
# 4.815188331229425
# 4.8153729356580826
# 4.815188331229425
# 4.8152806334349965
# 4.815188331229425
# 4.814911424718477
# 4.815003726871098
# 4.815096029041437
# 4.815003726871098
# 4.814911424718477
# 4.815188331229425
# 4.815003726871098
# 4.8152806334349965
# 4.814819122583637
# 4.8152806334349965
# 4.815096029041437
# 4.815188331229425
# 4.815003726871098
# 4.815188331229425
# 4.815188331229425
# 4.815096029041437
# 4.814726820466648
# 4.815188331229425
# 4.815096029041437
# 4.815188331229425
# 4.815096029041437
# 4.815096029041437
# 4.815003726871098
# 4.815188331229425
# 4.814911424718477
# 4.815003726871098
# 4.815003726871098
# 4.815188331229425
# 4.815003726871098
# 4.8152806334349965
# 4.815096029041437
# 4.815096029041437
# 4.8153729356580826
# 4.815096029041437
# 4.8152806334349965
# 4.815188331229425
# 4.815465237898619
# 4.815188331229425
# 4.815096029041437
# 4.815188331229425
# 4.8153729356580826
# 4.815003726871098
# 4.815188331229425
# 4.8152806334349965
# 4.815096029041437
# 4.814911424718477
# 4.815003726871098
# 4.8152806334349965
# 4.815188331229425
# 4.815188331229425
# 4.815096029041437
# 4.815003726871098
# 4.815188331229425
# 4.8152806334349965
# 4.8152806334349965
# 4.815188331229425
# 4.815084236257232
# 4.815003726871098
# 4.8152806334349965
# 4.815096029041437
# 4.815096385298154
# 4.815003726871098
# 4.815096029041437
# 4.815003726871098

# %%
def hexagon_vacancy():
    @pb.site_state_modifier
    def modifier(state, sub_id):
        state[sub_id=='54'] = False
        state[sub_id=='55'] = False
        state[sub_id=='56'] = False
        state[sub_id=='57'] = False
        state[sub_id=='72'] = False
        state[sub_id=='71'] = False
        return state
    return modifier
model = pb.Model(
    graphene_model(),
    pb.translational_symmetry(a1=True, a2= True),
    hexagon_vacancy()
)
#print(model3_v.hamiltonian.todense())

#model3_v.onsite_map.plot_contourf()
#pb.pltutils.colorbar(label="U (eV)")
model.plot()
plt.title('Model system')
# Out:
# Text(0.5, 1.0, 'Model system')

# %%
from pybinding.repository import graphene
from math import sqrt, pi

solver = pb.solver.lapack(model)
#print(solver.eigenvalues)

plt.subplot(142)
bands = solver.calc_bands(-pi/(7*graphene.a), pi/(7*graphene.a)) #in the first Brillouin zone, for kx
bands.plot(point_labels=[r"$-\pi / a$", r"$\pi / a$"])
plt.title('Band structure')
plt.show()

plt.subplot(143)
dos = solver.calc_dos(energies=np.linspace(-10, 10, 200), broadening=0.1)  # [eV]
dos.plot()
plt.title('Density of states')
plt.show()
print(dos.data[100])

plt.subplot(144)
reference_energy=0
ldos_map = solver.calc_spatial_ldos(energy=reference_energy, broadening=0.05)  # [eV]
ldos_map.plot()
pb.pltutils.colorbar(label='at energy %d'%reference_energy)
plt.title('Local density of states')
plt.show()
# Out:
# 3.3652169141984785

# %% [markdown]
# ## vacancy & addatom

# %%
def hexagon_vacancy():
    @pb.site_state_modifier
    def modifier(state, sub_id):
        state[sub_id=='54'] = False
        state[sub_id=='55'] = False
        state[sub_id=='56'] = False
        state[sub_id=='57'] = False
        state[sub_id=='72'] = False
        state[sub_id=='71'] = False
        return state
    return modifier
def addatom(delta_energy):
    @pb.onsite_energy_modifier
    def potential(energy, sub_id):
        energy[sub_id == '38'] += delta_energy
        energy[sub_id == '41'] += delta_energy
        energy[sub_id == '58'] += delta_energy
        energy[sub_id == '73'] += delta_energy
        energy[sub_id == '70'] += delta_energy
        energy[sub_id == '53'] += delta_energy
        return energy
    return potential

model = pb.Model(
    graphene_model(),
    pb.translational_symmetry(a1=True, a2= True),
    addatom(1),
    hexagon_vacancy()
)
#print(model3.hamiltonian.todense())

model.onsite_map.plot_contourf()
pb.pltutils.colorbar(label="U (eV)")
model.plot()
plt.title('Model system')
#model.lattice.plot_vectors(position=[0.6, -0.25])
# Out:
# Text(0.5, 1.0, 'Model system')

# %%
from pybinding.repository import graphene
from math import sqrt, pi

solver = pb.solver.lapack(model)
#print(solver.eigenvalues)

plt.subplot(142)
bands = solver.calc_bands(-pi/(7*graphene.a), pi/(7*graphene.a)) #in the first Brillouin zone, for kx
bands.plot(point_labels=[r"$-\pi / a$", r"$\pi / a$"])
plt.title('Band structure')
plt.show()

plt.subplot(143)
dos = solver.calc_dos(energies=np.linspace(-10, 10, 200), broadening=0.05)  # [eV]
dos.plot()
plt.title('Density of states')
plt.show()
print(dos.data[100])

plt.subplot(144)
reference_energy=0
ldos_map = solver.calc_spatial_ldos(energy=reference_energy, broadening=0.05)  # [eV]
ldos_map.plot()
pb.pltutils.colorbar(label='at energy %d'%reference_energy)
plt.title('Local density of states')
plt.show()
# Out:
# 5.089018904128518

# %%
from pybinding.repository import graphene
from math import sqrt, pi

kx=np.linspace(-pi/(7*graphene.a), pi/(7*graphene.a),500)
ky=np.linspace(-pi/(12*graphene.a/sqrt(3)), pi/(12*graphene.a/sqrt(3)),500)

solver = pb.solver.lapack(model)
solver.set_wave_vector([0,0])
lapack_dos = solver.calc_dos(np.linspace(-7, 7, 500), broadening=0.01)
data1=lapack_dos.data
for i in range(0,500):
    solver = pb.solver.lapack(model)
    solver.set_wave_vector([kx[i],ky[i]])
    lapack_dos = solver.calc_dos(np.linspace(-7, 7, 500), broadening=0.01)
    data1+=lapack_dos.data
data1=data1/501
#plt.plot(data1, np.linspace(-7, 7, 500),label='position: [4.5,3]',color='b')   # To switch the x and y axis
#plt.ylim(-0.5, 0.5)
plt.plot(np.linspace(-7, 7, 500),data1)
